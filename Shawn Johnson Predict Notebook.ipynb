# %% [markdown]
# # Unsupervised Learning Predict:
# ## Movie Recommendation Challenge

# %% [markdown]
# Load packages

# %%
import pandas as pd
import numpy as np

# %%
# Modeling packages
from surprise import Reader
from surprise import Dataset
from surprise import KNNWithMeans 
from surprise import KNNBasic
from surprise.model_selection import cross_validate
from surprise.model_selection import train_test_split
from surprise.model_selection import GridSearchCV
from surprise import SVD
from surprise import SVDpp
from surprise import NMF
from surprise import SlopeOne
from surprise import CoClustering
import heapq

# %% [markdown]
# ### Load and explore datasets

# %%
train = pd.read_csv('train.csv')
train.head()
# Out:
#    userId  movieId  rating   timestamp
# 0    5163    57669     4.0  1518349992
# 1  106343        5     4.5  1206238739
# 2  146790     5459     5.0  1076215539
# 3  106362    32296     2.0  1423042565
# 4    9041      366     3.0   833375837

# %%
train.shape
# Out:
# (10000038, 4)

# %%
test = pd.read_csv('test.csv')
test.head()
# Out:
#    userId  movieId
# 0       1     2011
# 1       1     4144
# 2       1     5767
# 3       1     6711
# 4       1     7318

# %%
sample_submission = pd.read_csv('sample_submission.csv')
sample_submission.head()
# Out:
#        Id  rating
# 0  1_2011     1.0
# 1  1_4144     1.0
# 2  1_5767     1.0
# 3  1_6711     1.0
# 4  1_7318     1.0

# %%
sample_submission.tail()
# Out:
#                   Id  rating
# 5000014  162541_4079     1.0
# 5000015  162541_4467     1.0
# 5000016  162541_4980     1.0
# 5000017  162541_5689     1.0
# 5000018  162541_7153     1.0

# %%
tags = pd.read_csv('tags.csv')
tags.head()
# Out:
#    userId  movieId               tag   timestamp
# 0       3      260           classic  1439472355
# 1       3      260            sci-fi  1439472256
# 2       4     1732       dark comedy  1573943598
# 3       4     1732    great dialogue  1573943604
# 4       4     7569  so bad it's good  1573943455

# %%
genome_scores = pd.read_csv('genome_scores.csv')
genome_scores.head()
# Out:
#    movieId  tagId  relevance
# 0        1      1    0.02875
# 1        1      2    0.02375
# 2        1      3    0.06250
# 3        1      4    0.07575
# 4        1      5    0.14075

# %%
genome_tags = pd.read_csv('genome_tags.csv')
genome_tags.head()
# Out:
#    tagId           tag
# 0      1           007
# 1      2  007 (series)
# 2      3  18th century
# 3      4         1920s
# 4      5         1930s

# %%
imdb_data = pd.read_csv('imdb_data.csv')
imdb_data.head()
# Out:
#    movieId                                         title_cast  \
# 0        1  Tom Hanks|Tim Allen|Don Rickles|Jim Varney|Wal...
# 1        2  Robin Williams|Jonathan Hyde|Kirsten Dunst|Bra...
# 2        3  Walter Matthau|Jack Lemmon|Sophia Loren|Ann-Ma...
# 3        4  Whitney Houston|Angela Bassett|Loretta Devine|...
# 4        5  Steve Martin|Diane Keaton|Martin Short|Kimberl...
#
#               director  runtime       budget  \
# 0        John Lasseter     81.0  $30,000,000
# 1   Jonathan Hensleigh    104.0  $65,000,000
# 2  Mark Steven Johnson    101.0  $25,000,000
# 3       Terry McMillan    124.0  $16,000,000
# 4       Albert Hackett    106.0  $30,000,000
#
#                                        plot_keywords
# 0                   toy|rivalry|cowboy|cgi animation
# 1                   board game|adventurer|fight|game
# 2                         boat|lake|neighbor|rivalry
# 3  black american|husband wife relationship|betra...
# 4                    fatherhood|doberman|dog|mansion

# %%
links = pd.read_csv('links.csv')
links.head()
# Out:
#    movieId  imdbId   tmdbId
# 0        1  114709    862.0
# 1        2  113497   8844.0
# 2        3  113228  15602.0
# 3        4  114885  31357.0
# 4        5  113041  11862.0

# %%
movies = pd.read_csv('movies.csv')
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
print(tags.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1093360 entries, 0 to 1093359
# Data columns (total 4 columns):
#  #   Column     Non-Null Count    Dtype
# ---  ------     --------------    -----
#  0   userId     1093360 non-null  int64
#  1   movieId    1093360 non-null  int64
#  2   tag        1093344 non-null  object
#  3   timestamp  1093360 non-null  int64
# dtypes: int64(3), object(1)
# memory usage: 33.4+ MB
# None

# %%
print(genome_scores.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15584448 entries, 0 to 15584447
# Data columns (total 3 columns):
#  #   Column     Dtype
# ---  ------     -----
#  0   movieId    int64
#  1   tagId      int64
#  2   relevance  float64
# dtypes: float64(1), int64(2)
# memory usage: 356.7 MB
# None

# %%
print(genome_tags.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1128 entries, 0 to 1127
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   tagId   1128 non-null   int64
#  1   tag     1128 non-null   object
# dtypes: int64(1), object(1)
# memory usage: 17.8+ KB
# None

# %%
print(imdb_data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27278 entries, 0 to 27277
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   movieId        27278 non-null  int64
#  1   title_cast     17210 non-null  object
#  2   director       17404 non-null  object
#  3   runtime        15189 non-null  float64
#  4   budget         7906 non-null   object
#  5   plot_keywords  16200 non-null  object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 1.2+ MB
# None

# %%
print(links.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62423 entries, 0 to 62422
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   movieId  62423 non-null  int64
#  1   imdbId   62423 non-null  int64
#  2   tmdbId   62316 non-null  float64
# dtypes: float64(1), int64(2)
# memory usage: 1.4 MB
# None

# %%
print(movies.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62423 entries, 0 to 62422
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   movieId  62423 non-null  int64
#  1   title    62423 non-null  object
#  2   genres   62423 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 1.4+ MB
# None

# %% [markdown]
# ### Build utility matrix, merging relevant dataframes

# %%
df_1 = train.merge(movies, on='movieId')
df_1.head(3)
# Out:
#    userId  movieId  rating   timestamp             title  \
# 0    5163    57669     4.0  1518349992  In Bruges (2008)
# 1   87388    57669     3.5  1237455297  In Bruges (2008)
# 2  137050    57669     4.0  1425631854  In Bruges (2008)
#
#                         genres
# 0  Comedy|Crime|Drama|Thriller
# 1  Comedy|Crime|Drama|Thriller
# 2  Comedy|Crime|Drama|Thriller

# %%
df_2 = df_1.merge(imdb_data, on='movieId')

# %%
df_2.head(3)
# Out:
#    userId  movieId  rating   timestamp             title  \
# 0    5163    57669     4.0  1518349992  In Bruges (2008)
# 1   87388    57669     3.5  1237455297  In Bruges (2008)
# 2  137050    57669     4.0  1425631854  In Bruges (2008)
#
#                         genres  \
# 0  Comedy|Crime|Drama|Thriller
# 1  Comedy|Crime|Drama|Thriller
# 2  Comedy|Crime|Drama|Thriller
#
#                                           title_cast         director  \
# 0  Elizabeth Berrington|Rudy Blomme|Olivier Bonjo...  Martin McDonagh
# 1  Elizabeth Berrington|Rudy Blomme|Olivier Bonjo...  Martin McDonagh
# 2  Elizabeth Berrington|Rudy Blomme|Olivier Bonjo...  Martin McDonagh
#
#    runtime       budget              plot_keywords
# 0    107.0  $15,000,000  dwarf|bruges|irish|hitman
# 1    107.0  $15,000,000  dwarf|bruges|irish|hitman
# 2    107.0  $15,000,000  dwarf|bruges|irish|hitman

# %%
df_1.isnull().sum()
# Out:
# userId       0
# movieId      0
# rating       0
# timestamp    0
# title        0
# genres       0
# dtype: int64

# %%
df_2.plot_keywords
# Out:
# 0                              dwarf|bruges|irish|hitman
# 1                              dwarf|bruges|irish|hitman
# 2                              dwarf|bruges|irish|hitman
# 3                              dwarf|bruges|irish|hitman
# 4                              dwarf|bruges|irish|hitman
#                                ...
# 9633026                                              NaN
# 9633027    janitor|income|housing problem|social problem
# 9633028                                              NaN
# 9633029                   soldier|italy|partisan|fascist
# 9633030           genius|artist|greek american|direction
# Name: plot_keywords, Length: 9633031, dtype: object

# %%
train['rating'].describe()
# Out:
# count    1.000004e+07
# mean     3.533395e+00
# std      1.061124e+00
# min      5.000000e-01
# 25%      3.000000e+00
# 50%      3.500000e+00
# 75%      4.000000e+00
# max      5.000000e+00
# Name: rating, dtype: float64

# %%
df_2.isnull().sum()
# Out:
# userId                 0
# movieId                0
# rating                 0
# timestamp              0
# title                  0
# genres                 0
# title_cast       2604407
# director         2602688
# runtime          2653058
# budget           3152276
# plot_keywords    2610043
# dtype: int64

# %%
train.head()
# Out:
#    userId  movieId  rating   timestamp
# 0    5163    57669     4.0  1518349992
# 1  106343        5     4.5  1206238739
# 2  146790     5459     5.0  1076215539
# 3  106362    32296     2.0  1423042565
# 4    9041      366     3.0   833375837

# %% [markdown]
# ### Build movie recommender function, rating independent movie_id by user_id

# %%
# Create small test dataframe to evaluate models
tests = train.copy()
tests.drop(['timestamp'], axis=1, inplace=True)
tests = tests.head(20000)

# Create training data
reader = Reader(rating_scale=(0.5, 5))
test_data = Dataset.load_from_df(tests[['userId', 'movieId', 'rating']], reader)

# Compute similarities between users using cosine distance
sim_options = {'name': 'cosine',
              'user_based': True}

# Evaluate model
user = KNNWithMeans(sim_options=sim_options)
cv = cross_validate(user, test_data, cv=5, measures=['RMSE'], verbose=True)
# Out:
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE of algorithm KNNWithMeans on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    1.1331  1.1285  1.1267  1.1143  1.1113  1.1228  0.0085
# Fit time          4.73    3.57    3.56    2.58    2.97    3.48    0.73
# Test time         0.05    0.04    0.04    0.03    0.04    0.04    0.01

# %%
# Compute similarities between items using cosine distance
sim_options = {'name': 'cosine',
              'user_based': False}

# Fit KNNwithmeans algorithm to training set
item_based = KNNWithMeans(sim_options=sim_options)

# Evaluate model
cv = cross_validate(item_based, test_data, cv=5, measures=['RMSE'], verbose=True)
# Out:
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE of algorithm KNNWithMeans on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    1.0848  1.0837  1.0876  1.0892  1.0801  1.0851  0.0032
# Fit time          0.21    0.21    0.21    0.20    0.22    0.21    0.01
# Test time         0.03    0.03    0.02    0.03    0.02    0.03    0.00

# %%
# Load Surprise dataframe
train_df = train.copy()
reader = Reader()

#Select data for model training
data = Dataset.load_from_df(train_df[['userId', 'movieId', 'rating']], reader)

# %%
# Split data
trainset, testset = train_test_split(data, test_size=0.2)

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000038 entries, 0 to 10000037
# Data columns (total 4 columns):
#  #   Column     Dtype
# ---  ------     -----
#  0   userId     int64
#  1   movieId    int64
#  2   rating     float64
#  3   timestamp  int64
# dtypes: float64(1), int64(3)
# memory usage: 305.2 MB

# %%
# create instance for algorithm
svd = SVD()

# Fit to trainset
svd.fit(trainset)

# %%
pred = svd.test(testset)
print(pred)

test_df = pd.DataFrame(pred)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
test.head()
# Out:
#    userId  movieId
# 0       1     2011
# 1       1     4144
# 2       1     5767
# 3       1     6711
# 4       1     7318

# %%
ratings_predictions = [svd.predict(row.userId, row.movieId) for _, row in test.iterrows()]
ratings_predictions
# Out:
# [Prediction(uid=1, iid=2011, r_ui=None, est=3.3336432227249486, details={'was_impossible': False}),
#  Prediction(uid=1, iid=4144, r_ui=None, est=4.0439755930557775, details={'was_impossible': False}),
#  Prediction(uid=1, iid=5767, r_ui=None, est=3.7849049130684884, details={'was_impossible': False}),
#  Prediction(uid=1, iid=6711, r_ui=None, est=3.7392975065996343, details={'was_impossible': False}),
#  Prediction(uid=1, iid=7318, r_ui=None, est=3.4587777683779644, details={'was_impossible': False}),
#  Prediction(uid=1, iid=8405, r_ui=None, est=3.9892293089623756, details={'was_impossible': False}),
#  Prediction(uid=1, iid=8786, r_ui=None, est=4.2787694014716005, details={'was_impossible': False}),
#  Prediction(uid=2, iid=150, r_ui=None, est=3.5450845613072675, details={'was_impossible': False}),
#  Prediction(uid=2, iid=356, r_ui=None, est=3.6806222096162178, details={'was_impossible': False}),
#  Prediction(uid=2, iid=497, r_ui=None, est=3.4025332173570386, details={'was_impossible': False}),
#  Prediction(uid=2, iid=588, r_ui=None, est=3.1116736580878355, details={'was_impossible': False}),
#  Prediction(uid=2, iid=653, r_ui=None, est=3.0658627767766786, details={'was_impossible': False}),
#  Prediction(uid=2, iid=1080, r_ui=None, est=3.8690034639614774, details={'was_impossible': False}),
#  Prediction(uid=2, iid=1196, r_ui=None, est=4.571781186242349, details={'was_impossible': False}),
#  Prediction(uid=2, iid=1198, r_ui=None, est=4.1356629146009976, details={'was_impossible': False}),
#  Prediction(uid=2, iid=1201, r_ui=None, est=3.941721181079736, details={'was_impossible': False}),
#  Prediction(uid=2, iid=1299, r_ui=None, est=3.8789466640910897, details={'was_impossible': False}),
#  Prediction(uid=2, iid=1485, r_ui=None, est=2.81178186200398, details={'was_impossible': False}),
#  Prediction(uid=2, iid=1580, r_ui=None, est=3.717069077546276, details={'was_impossible': False}),
#  Prediction(uid=2, iid=1693, r_ui=None, est=3.262053327672579, details={'was_impossible': False}),
#  Prediction(uid=2, iid=2028, r_ui=None, est=4.234737632203022, details={'was_impossible': False}),
#  Prediction(uid=2, iid=2083, r_ui=None, est=3.181686884173678, details={'was_impossible': False}),
#  Prediction(uid=2, iid=2617, r_ui=None, est=3.02724562003128, details={'was_impossible': False}),
#  Prediction(uid=2, iid=2640, r_ui=None, est=2.9580820541633797, details={'was_impossible': False}),
#  Prediction(uid=2, iid=2918, r_ui=None, est=3.601298658124554, details={'was_impossible': False}),
#  Prediction(uid=2, iid=3098, r_ui=None, est=3.6544559519709128, details={'was_impossible': False}),
#  Prediction(uid=2, iid=3114, r_ui=None, est=3.837396088771934, details={'was_impossible': False}),
#  Prediction(uid=2, iid=3510, r_ui=None, est=3.2469404952584173, details={'was_impossible': False}),
#  Prediction(uid=2, iid=3994, r_ui=None, est=3.8835197878510885, details={'was_impossible': False}),
#  Prediction(uid=2, iid=4103, r_ui=None, est=3.5853640262890223, details={'was_impossible': False}),
#  Prediction(uid=2, iid=4963, r_ui=None, est=4.044505140165876, details={'was_impossible': False}),
#  Prediction(uid=2, iid=5103, r_ui=None, est=3.2037510488854366, details={'was_impossible': False}),
#  Prediction(uid=2, iid=5955, r_ui=None, est=3.4265101994673715, details={'was_impossible': False}),
#  Prediction(uid=2, iid=6156, r_ui=None, est=3.0957103569352715, details={'was_impossible': False}),
#  Prediction(uid=2, iid=6287, r_ui=None, est=3.1133626228574043, details={'was_impossible': False}),
#  Prediction(uid=2, iid=6311, r_ui=None, est=3.504254696727238, details={'was_impossible': False}),
#  Prediction(uid=2, iid=6753, r_ui=None, est=3.7147901688855547, details={'was_impossible': False}),
#  Prediction(uid=2, iid=7075, r_ui=None, est=3.5035654275455466, details={'was_impossible': False}),
#  Prediction(uid=2, iid=7153, r_ui=None, est=5, details={'was_impossible': False}),
#  Prediction(uid=2, iid=7386, r_ui=None, est=3.0811678888362986, details={'was_impossible': False}),
#  Prediction(uid=2, iid=8961, r_ui=None, est=3.7588005025064883, details={'was_impossible': False}),
#  Prediction(uid=2, iid=30848, r_ui=None, est=3.737761103167863, details={'was_impossible': False}),
#  Prediction(uid=2, iid=33493, r_ui=None, est=4.07707578294245, details={'was_impossible': False}),
#  Prediction(uid=2, iid=34162, r_ui=None, est=3.597564065828016, details={'was_impossible': False}),
#  Prediction(uid=2, iid=40815, r_ui=None, est=4.240458852513484, details={'was_impossible': False}),
#  Prediction(uid=3, iid=1, r_ui=None, est=3.9933844475441553, details={'was_impossible': False}),
#  Prediction(uid=3, iid=260, r_ui=None, est=4.163912074933117, details={'was_impossible': False}),
#  Prediction(uid=3, iid=858, r_ui=None, est=4.762113376616934, details={'was_impossible': False}),
#  Prediction(uid=3, iid=1198, r_ui=None, est=3.9208221896189923, details={'was_impossible': False}),
#  Prediction(uid=3, iid=1201, r_ui=None, est=4.412434303546018, details={'was_impossible': False}),
#  Prediction(uid=3, iid=1214, r_ui=None, est=4.3205211960888255, details={'was_impossible': False}),
#  Prediction(uid=3, iid=1217, r_ui=None, est=4.517026832399308, details={'was_impossible': False}),
#  Prediction(uid=3, iid=1221, r_ui=None, est=4.645448042724008, details={'was_impossible': False}),
#  Prediction(uid=3, iid=1222, r_ui=None, est=4.306653785895917, details={'was_impossible': False}),
#  Prediction(uid=3, iid=1676, r_ui=None, est=3.5255615103257956, details={'was_impossible': False}),
#  Prediction(uid=3, iid=1909, r_ui=None, est=3.49404036171862, details={'was_impossible': False}),
#  Prediction(uid=3, iid=1960, r_ui=None, est=3.9614862363786743, details={'was_impossible': False}),
#  Prediction(uid=3, iid=3471, r_ui=None, est=3.867675167531975, details={'was_impossible': False}),
#  Prediction(uid=3, iid=3534, r_ui=None, est=3.228014502508953, details={'was_impossible': False}),
#  Prediction(uid=3, iid=3730, r_ui=None, est=4.33282239448061, details={'was_impossible': False}),
#  Prediction(uid=3, iid=3785, r_ui=None, est=3.0217797468228835, details={'was_impossible': False}),
#  Prediction(uid=3, iid=3948, r_ui=None, est=3.7204738534478987, details={'was_impossible': False}),
#  Prediction(uid=3, iid=3979, r_ui=None, est=2.8430360044846203, details={'was_impossible': False}),
#  Prediction(uid=3, iid=4025, r_ui=None, est=2.8940183407782674, details={'was_impossible': False}),
#  Prediction(uid=3, iid=4148, r_ui=None, est=3.8935784971638947, details={'was_impossible': False}),
#  Prediction(uid=3, iid=4383, r_ui=None, est=3.882926676553939, details={'was_impossible': False}),
#  Prediction(uid=3, iid=4816, r_ui=None, est=3.6270397343973952, details={'was_impossible': False}),
#  Prediction(uid=3, iid=4979, r_ui=None, est=4.349351894441739, details={'was_impossible': False}),
#  Prediction(uid=3, iid=5219, r_ui=None, est=3.6017845818722565, details={'was_impossible': False}),
#  Prediction(uid=3, iid=5254, r_ui=None, est=3.2799824596752836, details={'was_impossible': False}),
#  Prediction(uid=3, iid=5291, r_ui=None, est=4.370226626022624, details={'was_impossible': False}),
#  Prediction(uid=3, iid=5313, r_ui=None, est=2.89398592030408, details={'was_impossible': False}),
#  Prediction(uid=3, iid=5364, r_ui=None, est=3.352012896590885, details={'was_impossible': False}),
#  Prediction(uid=3, iid=5479, r_ui=None, est=3.640326147039715, details={'was_impossible': False}),
#  Prediction(uid=3, iid=5528, r_ui=None, est=3.6860855501225025, details={'was_impossible': False}),
#  Prediction(uid=3, iid=5669, r_ui=None, est=3.5255906213218147, details={'was_impossible': False}),
#  Prediction(uid=3, iid=5679, r_ui=None, est=3.454148364972423, details={'was_impossible': False}),
#  Prediction(uid=3, iid=5782, r_ui=None, est=4.390456941186922, details={'was_impossible': False}),
#  Prediction(uid=3, iid=5872, r_ui=None, est=3.534439554573458, details={'was_impossible': False}),
#  Prediction(uid=3, iid=5900, r_ui=None, est=3.4238692937587416, details={'was_impossible': False}),
#  Prediction(uid=3, iid=5944, r_ui=None, est=3.5232852847587033, details={'was_impossible': False}),
#  Prediction(uid=3, iid=5954, r_ui=None, est=4.067885550316762, details={'was_impossible': False}),
#  Prediction(uid=3, iid=6213, r_ui=None, est=3.380132200857409, details={'was_impossible': False}),
#  Prediction(uid=3, iid=6323, r_ui=None, est=3.93191650203381, details={'was_impossible': False}),
#  Prediction(uid=3, iid=6541, r_ui=None, est=3.4508715863568273, details={'was_impossible': False}),
#  Prediction(uid=3, iid=6586, r_ui=None, est=3.033325718635103, details={'was_impossible': False}),
#  Prediction(uid=3, iid=6934, r_ui=None, est=3.7354595444836804, details={'was_impossible': False}),
#  Prediction(uid=3, iid=6952, r_ui=None, est=3.1072866759000677, details={'was_impossible': False}),
#  Prediction(uid=3, iid=7163, r_ui=None, est=3.351751820845339, details={'was_impossible': False}),
#  Prediction(uid=3, iid=7438, r_ui=None, est=4.185156696619871, details={'was_impossible': False}),
#  Prediction(uid=3, iid=7439, r_ui=None, est=3.130298878550205, details={'was_impossible': False}),
#  Prediction(uid=3, iid=7445, r_ui=None, est=4.169111949263788, details={'was_impossible': False}),
#  Prediction(uid=3, iid=8360, r_ui=None, est=3.7969309864865894, details={'was_impossible': False}),
#  Prediction(uid=3, iid=8368, r_ui=None, est=3.911341361461631, details={'was_impossible': False}),
#  Prediction(uid=3, iid=8370, r_ui=None, est=4.237680976421361, details={'was_impossible': False}),
#  Prediction(uid=3, iid=8529, r_ui=None, est=3.8167896197895663, details={'was_impossible': False}),
#  Prediction(uid=3, iid=8641, r_ui=None, est=3.7856197013751833, details={'was_impossible': False}),
#  Prediction(uid=3, iid=8861, r_ui=None, est=3.4792318702352247, details={'was_impossible': False}),
#  Prediction(uid=3, iid=8874, r_ui=None, est=4.227571684543437, details={'was_impossible': False}),
#  Prediction(uid=3, iid=27706, r_ui=None, est=3.7116645196248306, details={'was_impossible': False}),
#  Prediction(uid=3, iid=27793, r_ui=None, est=2.507491018819942, details={'was_impossible': False}),
#  Prediction(uid=3, iid=31184, r_ui=None, est=3.7141003913157324, details={'was_impossible': False}),
#  Prediction(uid=3, iid=31685, r_ui=None, est=3.351658486772746, details={'was_impossible': False}),
#  Prediction(uid=3, iid=31696, r_ui=None, est=3.9996908347007984, details={'was_impossible': False}),
#  Prediction(uid=3, iid=31804, r_ui=None, est=4.050957733945067, details={'was_impossible': False}),
#  Prediction(uid=3, iid=33615, r_ui=None, est=3.7236700583371025, details={'was_impossible': False}),
#  Prediction(uid=3, iid=34150, r_ui=None, est=3.0639223413759376, details={'was_impossible': False}),
#  Prediction(uid=3, iid=34162, r_ui=None, est=3.4743786100495564, details={'was_impossible': False}),
#  Prediction(uid=3, iid=35836, r_ui=None, est=3.5437182081866494, details={'was_impossible': False}),
#  Prediction(uid=3, iid=37386, r_ui=None, est=3.3294900844673436, details={'was_impossible': False}),
#  Prediction(uid=3, iid=44022, r_ui=None, est=3.663901362818024, details={'was_impossible': False}),
#  Prediction(uid=3, iid=46972, r_ui=None, est=3.151417212081253, details={'was_impossible': False}),
#  Prediction(uid=3, iid=47610, r_ui=None, est=4.144697188189335, details={'was_impossible': False}),
#  Prediction(uid=3, iid=48780, r_ui=None, est=4.561634018553218, details={'was_impossible': False}),
#  Prediction(uid=3, iid=49272, r_ui=None, est=3.9724240085124998, details={'was_impossible': False}),
#  Prediction(uid=3, iid=49278, r_ui=None, est=3.954867800111461, details={'was_impossible': False}),
#  Prediction(uid=3, iid=49530, r_ui=None, est=4.067534874668603, details={'was_impossible': False}),
#  Prediction(uid=3, iid=51255, r_ui=None, est=4.040638155458687, details={'was_impossible': False}),
#  Prediction(uid=3, iid=53121, r_ui=None, est=3.3549276771361933, details={'was_impossible': False}),
#  Prediction(uid=3, iid=53129, r_ui=None, est=3.9507394783890697, details={'was_impossible': False}),
#  Prediction(uid=3, iid=53464, r_ui=None, est=2.9894690930958703, details={'was_impossible': False}),
#  Prediction(uid=3, iid=55765, r_ui=None, est=4.205765438051238, details={'was_impossible': False}),
#  Prediction(uid=3, iid=55805, r_ui=None, est=3.9061390881136027, details={'was_impossible': False}),
#  Prediction(uid=3, iid=58559, r_ui=None, est=4.461721750350538, details={'was_impossible': False}),
#  Prediction(uid=3, iid=59315, r_ui=None, est=4.056321342411583, details={'was_impossible': False}),
#  Prediction(uid=3, iid=59501, r_ui=None, est=3.504835634099599, details={'was_impossible': False}),
#  Prediction(uid=3, iid=60069, r_ui=None, est=4.133028940264025, details={'was_impossible': False}),
#  Prediction(uid=3, iid=61350, r_ui=None, est=3.135557321666011, details={'was_impossible': False}),
#  Prediction(uid=3, iid=64839, r_ui=None, est=3.9858651621780923, details={'was_impossible': False}),
#  Prediction(uid=3, iid=68319, r_ui=None, est=3.674980428168422, details={'was_impossible': False}),
#  Prediction(uid=3, iid=68793, r_ui=None, est=3.1724787465231437, details={'was_impossible': False}),
#  Prediction(uid=3, iid=68952, r_ui=None, est=3.5716552725955197, details={'was_impossible': False}),
#  Prediction(uid=3, iid=71057, r_ui=None, est=3.998180420991215, details={'was_impossible': False}),
#  Prediction(uid=3, iid=71464, r_ui=None, est=3.9949964765858605, details={'was_impossible': False}),
#  Prediction(uid=3, iid=72209, r_ui=None, est=3.6034073736249153, details={'was_impossible': False}),
#  Prediction(uid=3, iid=74789, r_ui=None, est=3.7133523907392463, details={'was_impossible': False}),
#  Prediction(uid=3, iid=76077, r_ui=None, est=3.2628186624904836, details={'was_impossible': False}),
#  Prediction(uid=3, iid=78499, r_ui=None, est=3.809543593238068, details={'was_impossible': False}),
#  Prediction(uid=3, iid=81845, r_ui=None, est=4.115179368824998, details={'was_impossible': False}),
#  Prediction(uid=3, iid=82202, r_ui=None, est=3.4675206235100124, details={'was_impossible': False}),
#  Prediction(uid=3, iid=85020, r_ui=None, est=3.70716184944808, details={'was_impossible': False}),
#  Prediction(uid=3, iid=85056, r_ui=None, est=3.047486379124888, details={'was_impossible': False}),
#  Prediction(uid=3, iid=88140, r_ui=None, est=3.633348222094999, details={'was_impossible': False}),
#  Prediction(uid=3, iid=96610, r_ui=None, est=3.9407872554030265, details={'was_impossible': False}),
#  Prediction(uid=3, iid=97225, r_ui=None, est=3.6143820350031777, details={'was_impossible': False}),
#  Prediction(uid=3, iid=102445, r_ui=None, est=3.8152316210233153, details={'was_impossible': False}),
#  Prediction(uid=3, iid=102880, r_ui=None, est=2.384031982983167, details={'was_impossible': False}),
#  Prediction(uid=3, iid=102903, r_ui=None, est=4.00716176876863, details={'was_impossible': False}),
#  Prediction(uid=3, iid=103141, r_ui=None, est=3.6914146282820006, details={'was_impossible': False}),
#  Prediction(uid=3, iid=103772, r_ui=None, est=3.503075614408491, details={'was_impossible': False}),
#  Prediction(uid=3, iid=105213, r_ui=None, est=3.4375635473994683, details={'was_impossible': False}),
#  Prediction(uid=3, iid=109374, r_ui=None, est=4.303024144805701, details={'was_impossible': False}),
#  Prediction(uid=3, iid=109487, r_ui=None, est=4.1991874294125955, details={'was_impossible': False}),
#  Prediction(uid=3, iid=111443, r_ui=None, est=3.964752464415509, details={'was_impossible': False}),
#  Prediction(uid=3, iid=111659, r_ui=None, est=3.3634726275230724, details={'was_impossible': False}),
#  Prediction(uid=3, iid=112138, r_ui=None, est=3.8123787777148426, details={'was_impossible': False}),
#  Prediction(uid=3, iid=114847, r_ui=None, est=3.70218410441198, details={'was_impossible': False}),
#  Prediction(uid=3, iid=115569, r_ui=None, est=4.192339228141255, details={'was_impossible': False}),
#  Prediction(uid=3, iid=116897, r_ui=None, est=4.608839167252664, details={'was_impossible': False}),
#  Prediction(uid=3, iid=117529, r_ui=None, est=3.497034918817363, details={'was_impossible': False}),
#  Prediction(uid=3, iid=122912, r_ui=None, est=3.68399391154366, details={'was_impossible': False}),
#  Prediction(uid=3, iid=135143, r_ui=None, est=3.793033623885889, details={'was_impossible': False}),
#  Prediction(uid=3, iid=136449, r_ui=None, est=4.342141174674826, details={'was_impossible': False}),
#  Prediction(uid=3, iid=143385, r_ui=None, est=3.9408093195474905, details={'was_impossible': False}),
#  Prediction(uid=3, iid=151763, r_ui=None, est=3.9343438686861503, details={'was_impossible': False}),
#  Prediction(uid=4, iid=1036, r_ui=None, est=3.6058914454630004, details={'was_impossible': False}),
#  Prediction(uid=4, iid=1136, r_ui=None, est=4.393284289214146, details={'was_impossible': False}),
#  Prediction(uid=4, iid=1196, r_ui=None, est=3.8015453491980185, details={'was_impossible': False}),
#  Prediction(uid=4, iid=1220, r_ui=None, est=3.897309262724769, details={'was_impossible': False}),
#  Prediction(uid=4, iid=1907, r_ui=None, est=3.2689270129635513, details={'was_impossible': False}),
#  Prediction(uid=4, iid=2716, r_ui=None, est=3.183254824482541, details={'was_impossible': False}),
#  Prediction(uid=4, iid=2985, r_ui=None, est=2.714688006770003, details={'was_impossible': False}),
#  Prediction(uid=4, iid=3114, r_ui=None, est=3.845014075690018, details={'was_impossible': False}),
#  Prediction(uid=4, iid=3671, r_ui=None, est=3.7986368778639377, details={'was_impossible': False}),
#  Prediction(uid=4, iid=4709, r_ui=None, est=3.5062890639067255, details={'was_impossible': False}),
#  Prediction(uid=4, iid=4816, r_ui=None, est=3.627636614130347, details={'was_impossible': False}),
#  Prediction(uid=4, iid=5110, r_ui=None, est=3.631235041302093, details={'was_impossible': False}),
#  Prediction(uid=4, iid=5418, r_ui=None, est=3.8103677781661114, details={'was_impossible': False}),
#  Prediction(uid=4, iid=5903, r_ui=None, est=3.577637406334584, details={'was_impossible': False}),
#  Prediction(uid=4, iid=6863, r_ui=None, est=3.308320342738708, details={'was_impossible': False}),
#  Prediction(uid=4, iid=7438, r_ui=None, est=3.974638963977839, details={'was_impossible': False}),
#  Prediction(uid=4, iid=7569, r_ui=None, est=3.667299025417686, details={'was_impossible': False}),
#  Prediction(uid=4, iid=8665, r_ui=None, est=3.580653885648198, details={'was_impossible': False}),
#  Prediction(uid=4, iid=34048, r_ui=None, est=2.80844705388089, details={'was_impossible': False}),
#  Prediction(uid=4, iid=45431, r_ui=None, est=3.039074582132819, details={'was_impossible': False}),
#  Prediction(uid=4, iid=49649, r_ui=None, est=1.6859562283801846, details={'was_impossible': False}),
#  Prediction(uid=4, iid=53125, r_ui=None, est=2.8175362930144425, details={'was_impossible': False}),
#  Prediction(uid=4, iid=69122, r_ui=None, est=3.497874442354524, details={'was_impossible': False}),
#  Prediction(uid=4, iid=77561, r_ui=None, est=2.6523010014085773, details={'was_impossible': False}),
#  Prediction(uid=4, iid=82461, r_ui=None, est=3.1580260534570876, details={'was_impossible': False}),
#  Prediction(uid=4, iid=83134, r_ui=None, est=3.576845108597711, details={'was_impossible': False}),
#  Prediction(uid=4, iid=85414, r_ui=None, est=3.562965049481862, details={'was_impossible': False}),
#  Prediction(uid=4, iid=86345, r_ui=None, est=4.510647275091249, details={'was_impossible': False}),
#  Prediction(uid=4, iid=88125, r_ui=None, est=3.203704703637464, details={'was_impossible': False}),
#  Prediction(uid=4, iid=91529, r_ui=None, est=3.662959518422868, details={'was_impossible': False}),
#  Prediction(uid=4, iid=93510, r_ui=None, est=3.596018097799526, details={'was_impossible': False}),
#  Prediction(uid=4, iid=93840, r_ui=None, est=3.52912501667867, details={'was_impossible': False}),
#  Prediction(uid=4, iid=96079, r_ui=None, est=3.636495294056987, details={'was_impossible': False}),
#  Prediction(uid=4, iid=96737, r_ui=None, est=3.2723167134492805, details={'was_impossible': False}),
#  Prediction(uid=4, iid=97304, r_ui=None, est=3.6783762442647676, details={'was_impossible': False}),
#  Prediction(uid=4, iid=103228, r_ui=None, est=3.217545521462259, details={'was_impossible': False}),
#  Prediction(uid=4, iid=103772, r_ui=None, est=2.5804098892826226, details={'was_impossible': False}),
#  Prediction(uid=4, iid=109487, r_ui=None, est=4.1297548717060675, details={'was_impossible': False}),
#  Prediction(uid=4, iid=111759, r_ui=None, est=3.6311684983217933, details={'was_impossible': False}),
#  Prediction(uid=4, iid=111781, r_ui=None, est=3.1362396206455934, details={'was_impossible': False}),
#  Prediction(uid=4, iid=112852, r_ui=None, est=3.5515219111485656, details={'was_impossible': False}),
#  Prediction(uid=4, iid=122882, r_ui=None, est=4.061519599908902, details={'was_impossible': False}),
#  Prediction(uid=4, iid=122918, r_ui=None, est=3.282871149533559, details={'was_impossible': False}),
#  Prediction(uid=4, iid=134130, r_ui=None, est=3.8449563886318683, details={'was_impossible': False}),
#  Prediction(uid=4, iid=136020, r_ui=None, est=3.0562994527438145, details={'was_impossible': False}),
#  Prediction(uid=4, iid=148626, r_ui=None, est=3.999091997378375, details={'was_impossible': False}),
#  Prediction(uid=4, iid=156706, r_ui=None, est=2.8519085511749607, details={'was_impossible': False}),
#  Prediction(uid=4, iid=159817, r_ui=None, est=4.399149935882683, details={'was_impossible': False}),
#  Prediction(uid=4, iid=189333, r_ui=None, est=3.4871881986468574, details={'was_impossible': False}),
#  Prediction(uid=5, iid=36, r_ui=None, est=4.26785174075565, details={'was_impossible': False}),
#  Prediction(uid=5, iid=122, r_ui=None, est=3.2144988897198594, details={'was_impossible': False}),
#  Prediction(uid=5, iid=147, r_ui=None, est=4.132242366746476, details={'was_impossible': False}),
#  Prediction(uid=5, iid=191, r_ui=None, est=2.9743591340937408, details={'was_impossible': False}),
#  Prediction(uid=5, iid=218, r_ui=None, est=3.7346612246053708, details={'was_impossible': False}),
#  Prediction(uid=5, iid=231, r_ui=None, est=3.487719937573351, details={'was_impossible': False}),
#  Prediction(uid=5, iid=248, r_ui=None, est=3.399685393007512, details={'was_impossible': False}),
#  Prediction(uid=5, iid=253, r_ui=None, est=3.6655050577661554, details={'was_impossible': False}),
#  Prediction(uid=5, iid=277, r_ui=None, est=4.101672606628642, details={'was_impossible': False}),
#  Prediction(uid=5, iid=333, r_ui=None, est=3.879022802665655, details={'was_impossible': False}),
#  Prediction(uid=5, iid=337, r_ui=None, est=4.27378822984035, details={'was_impossible': False}),
#  Prediction(uid=5, iid=344, r_ui=None, est=3.8428828442886216, details={'was_impossible': False}),
#  Prediction(uid=5, iid=372, r_ui=None, est=3.5778694904209747, details={'was_impossible': False}),
#  Prediction(uid=5, iid=435, r_ui=None, est=2.7907272496437403, details={'was_impossible': False}),
#  Prediction(uid=5, iid=441, r_ui=None, est=3.9578804104791163, details={'was_impossible': False}),
#  Prediction(uid=5, iid=457, r_ui=None, est=4.363313749559522, details={'was_impossible': False}),
#  Prediction(uid=5, iid=491, r_ui=None, est=3.582134495674033, details={'was_impossible': False}),
#  Prediction(uid=5, iid=608, r_ui=None, est=4.613738515608191, details={'was_impossible': False}),
#  Prediction(uid=5, iid=628, r_ui=None, est=4.074418413278458, details={'was_impossible': False}),
#  Prediction(uid=5, iid=780, r_ui=None, est=3.8368560250630885, details={'was_impossible': False}),
#  Prediction(uid=5, iid=1016, r_ui=None, est=3.29965653917171, details={'was_impossible': False}),
#  Prediction(uid=5, iid=1196, r_ui=None, est=4.534626315690685, details={'was_impossible': False}),
#  Prediction(uid=5, iid=1235, r_ui=None, est=4.479844171790658, details={'was_impossible': False}),
#  Prediction(uid=5, iid=1270, r_ui=None, est=4.268803110239529, details={'was_impossible': False}),
#  Prediction(uid=6, iid=161, r_ui=None, est=3.913762399245713, details={'was_impossible': False}),
#  Prediction(uid=6, iid=260, r_ui=None, est=3.9754533774020198, details={'was_impossible': False}),
#  Prediction(uid=6, iid=608, r_ui=None, est=4.346714330983689, details={'was_impossible': False}),
#  Prediction(uid=6, iid=919, r_ui=None, est=3.7734255446714506, details={'was_impossible': False}),
#  Prediction(uid=6, iid=1466, r_ui=None, est=4.009089378773312, details={'was_impossible': False}),
#  Prediction(uid=6, iid=1704, r_ui=None, est=4.269857204129742, details={'was_impossible': False}),
#  Prediction(uid=7, iid=17, r_ui=None, est=4.292040950111428, details={'was_impossible': False}),
#  Prediction(uid=7, iid=165, r_ui=None, est=3.2472060760401242, details={'was_impossible': False}),
#  Prediction(uid=7, iid=185, r_ui=None, est=3.1126241553992493, details={'was_impossible': False}),
#  Prediction(uid=7, iid=308, r_ui=None, est=4.003240112259914, details={'was_impossible': False}),
#  Prediction(uid=7, iid=590, r_ui=None, est=3.949023080351551, details={'was_impossible': False}),
#  Prediction(uid=8, iid=10, r_ui=None, est=3.5169908540704977, details={'was_impossible': False}),
#  Prediction(uid=8, iid=25, r_ui=None, est=3.84355570203647, details={'was_impossible': False}),
#  Prediction(uid=8, iid=27, r_ui=None, est=3.568616141878824, details={'was_impossible': False}),
#  Prediction(uid=8, iid=50, r_ui=None, est=4.224036972576263, details={'was_impossible': False}),
#  Prediction(uid=8, iid=69, r_ui=None, est=3.647526293460657, details={'was_impossible': False}),
#  Prediction(uid=8, iid=207, r_ui=None, est=2.8055158566822698, details={'was_impossible': False}),
#  Prediction(uid=8, iid=237, r_ui=None, est=3.585083631313822, details={'was_impossible': False}),
#  Prediction(uid=8, iid=260, r_ui=None, est=3.9209891878438374, details={'was_impossible': False}),
#  Prediction(uid=8, iid=356, r_ui=None, est=4.0069715080116115, details={'was_impossible': False}),
#  Prediction(uid=8, iid=440, r_ui=None, est=3.58528068384316, details={'was_impossible': False}),
#  Prediction(uid=8, iid=588, r_ui=None, est=3.0226070726509096, details={'was_impossible': False}),
#  Prediction(uid=8, iid=593, r_ui=None, est=4.0151597321835695, details={'was_impossible': False}),
#  Prediction(uid=8, iid=750, r_ui=None, est=3.9400437735803284, details={'was_impossible': False}),
#  Prediction(uid=8, iid=923, r_ui=None, est=3.8265637132545627, details={'was_impossible': False}),
#  Prediction(uid=8, iid=953, r_ui=None, est=3.6932145755300354, details={'was_impossible': False}),
#  Prediction(uid=8, iid=1020, r_ui=None, est=3.648399909467799, details={'was_impossible': False}),
#  Prediction(uid=8, iid=1047, r_ui=None, est=4.167109130231841, details={'was_impossible': False}),
#  Prediction(uid=8, iid=1092, r_ui=None, est=3.7813964804765914, details={'was_impossible': False}),
#  Prediction(uid=8, iid=1210, r_ui=None, est=3.8512600289963603, details={'was_impossible': False}),
#  Prediction(uid=8, iid=1240, r_ui=None, est=3.886977994605764, details={'was_impossible': False}),
#  Prediction(uid=8, iid=1259, r_ui=None, est=3.990694421227173, details={'was_impossible': False}),
#  Prediction(uid=8, iid=1287, r_ui=None, est=3.5966641229375083, details={'was_impossible': False}),
#  Prediction(uid=8, iid=1358, r_ui=None, est=3.9387679359306804, details={'was_impossible': False}),
#  Prediction(uid=8, iid=1370, r_ui=None, est=3.7490080666343126, details={'was_impossible': False}),
#  Prediction(uid=8, iid=1485, r_ui=None, est=3.8716329921885295, details={'was_impossible': False}),
#  Prediction(uid=8, iid=1552, r_ui=None, est=3.7175723097752975, details={'was_impossible': False}),
#  Prediction(uid=8, iid=1573, r_ui=None, est=3.4049809035250886, details={'was_impossible': False}),
#  Prediction(uid=8, iid=1584, r_ui=None, est=3.8407515956873826, details={'was_impossible': False}),
#  Prediction(uid=8, iid=1616, r_ui=None, est=2.99406106701349, details={'was_impossible': False}),
#  Prediction(uid=8, iid=1625, r_ui=None, est=4.1568489804877835, details={'was_impossible': False}),
#  Prediction(uid=8, iid=1645, r_ui=None, est=3.958647703158507, details={'was_impossible': False}),
#  Prediction(uid=8, iid=1747, r_ui=None, est=3.6014073033312415, details={'was_impossible': False}),
#  Prediction(uid=9, iid=10, r_ui=None, est=3.728801313986729, details={'was_impossible': False}),
#  Prediction(uid=9, iid=61, r_ui=None, est=3.856807714946874, details={'was_impossible': False}),
#  Prediction(uid=9, iid=105, r_ui=None, est=4.312749707277823, details={'was_impossible': False}),
#  Prediction(uid=9, iid=116, r_ui=None, est=4.302367739182447, details={'was_impossible': False}),
#  Prediction(uid=9, iid=161, r_ui=None, est=4.450528765230745, details={'was_impossible': False}),
#  Prediction(uid=9, iid=260, r_ui=None, est=4.485919261424403, details={'was_impossible': False}),
#  Prediction(uid=9, iid=355, r_ui=None, est=3.429608244306546, details={'was_impossible': False}),
#  Prediction(uid=9, iid=356, r_ui=None, est=4.8327825527082044, details={'was_impossible': False}),
#  Prediction(uid=9, iid=366, r_ui=None, est=3.6057267634313077, details={'was_impossible': False}),
#  Prediction(uid=9, iid=378, r_ui=None, est=3.7459198674427965, details={'was_impossible': False}),
#  Prediction(uid=9, iid=387, r_ui=None, est=3.4560315119188467, details={'was_impossible': False}),
#  Prediction(uid=9, iid=435, r_ui=None, est=2.9450987934273734, details={'was_impossible': False}),
#  Prediction(uid=9, iid=454, r_ui=None, est=4.1657389691220175, details={'was_impossible': False}),
#  Prediction(uid=9, iid=466, r_ui=None, est=3.5368600871173212, details={'was_impossible': False}),
#  Prediction(uid=9, iid=474, r_ui=None, est=4.370696845363613, details={'was_impossible': False}),
#  Prediction(uid=9, iid=516, r_ui=None, est=4.1354342892556035, details={'was_impossible': False}),
#  Prediction(uid=9, iid=541, r_ui=None, est=4.276922861748059, details={'was_impossible': False}),
#  Prediction(uid=9, iid=590, r_ui=None, est=4.2123083533299335, details={'was_impossible': False}),
#  Prediction(uid=9, iid=592, r_ui=None, est=3.3976207013873934, details={'was_impossible': False}),
#  Prediction(uid=9, iid=594, r_ui=None, est=4.2318508898810565, details={'was_impossible': False}),
#  Prediction(uid=9, iid=597, r_ui=None, est=4.601480653871567, details={'was_impossible': False}),
#  Prediction(uid=9, iid=616, r_ui=None, est=3.8093353212775627, details={'was_impossible': False}),
#  Prediction(uid=9, iid=667, r_ui=None, est=3.139349785621143, details={'was_impossible': False}),
#  Prediction(uid=9, iid=852, r_ui=None, est=3.94754575750485, details={'was_impossible': False}),
#  Prediction(uid=9, iid=971, r_ui=None, est=4.437864363376103, details={'was_impossible': False}),
#  Prediction(uid=9, iid=1005, r_ui=None, est=4.055456066417406, details={'was_impossible': False}),
#  Prediction(uid=9, iid=1010, r_ui=None, est=3.6179297259817838, details={'was_impossible': False}),
#  Prediction(uid=9, iid=1011, r_ui=None, est=3.4742817936973958, details={'was_impossible': False}),
#  Prediction(uid=9, iid=1018, r_ui=None, est=3.9387974916805626, details={'was_impossible': False}),
#  Prediction(uid=9, iid=1028, r_ui=None, est=4.453479059943116, details={'was_impossible': False}),
#  Prediction(uid=9, iid=1079, r_ui=None, est=3.8754726858599096, details={'was_impossible': False}),
#  Prediction(uid=9, iid=1097, r_ui=None, est=4.8161704249100366, details={'was_impossible': False}),
#  Prediction(uid=9, iid=1101, r_ui=None, est=4.7585063133401935, details={'was_impossible': False}),
#  Prediction(uid=9, iid=1124, r_ui=None, est=4.404331524185696, details={'was_impossible': False}),
#  Prediction(uid=9, iid=1125, r_ui=None, est=3.848010426110122, details={'was_impossible': False}),
#  Prediction(uid=9, iid=1127, r_ui=None, est=4.097411656307277, details={'was_impossible': False}),
#  Prediction(uid=9, iid=1200, r_ui=None, est=4.110332708566897, details={'was_impossible': False}),
#  Prediction(uid=9, iid=1221, r_ui=None, est=4.0087527084967745, details={'was_impossible': False}),
#  Prediction(uid=9, iid=1222, r_ui=None, est=4.142469279687773, details={'was_impossible': False}),
#  Prediction(uid=9, iid=1258, r_ui=None, est=4.158591283086372, details={'was_impossible': False}),
#  Prediction(uid=9, iid=1298, r_ui=None, est=4.055533275750548, details={'was_impossible': False}),
#  Prediction(uid=9, iid=1299, r_ui=None, est=4.31339141312358, details={'was_impossible': False}),
#  Prediction(uid=9, iid=1347, r_ui=None, est=3.841769222975549, details={'was_impossible': False}),
#  Prediction(uid=9, iid=1372, r_ui=None, est=4.033050151605758, details={'was_impossible': False}),
#  Prediction(uid=9, iid=1376, r_ui=None, est=4.1358860762489975, details={'was_impossible': False}),
#  Prediction(uid=9, iid=1381, r_ui=None, est=3.522127213749278, details={'was_impossible': False}),
#  Prediction(uid=10, iid=260, r_ui=None, est=4.5702350290253495, details={'was_impossible': False}),
#  Prediction(uid=10, iid=380, r_ui=None, est=3.5647810635223953, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1186, r_ui=None, est=3.336878245322797, details={'was_impossible': False}),
#  Prediction(uid=10, iid=2094, r_ui=None, est=2.801971340140893, details={'was_impossible': False}),
#  Prediction(uid=10, iid=2505, r_ui=None, est=3.418296632992919, details={'was_impossible': False}),
#  Prediction(uid=10, iid=2605, r_ui=None, est=3.063135639767759, details={'was_impossible': False}),
#  Prediction(uid=10, iid=2707, r_ui=None, est=3.3335379380303687, details={'was_impossible': False}),
#  Prediction(uid=10, iid=2944, r_ui=None, est=3.977988049349603, details={'was_impossible': False}),
#  Prediction(uid=10, iid=4361, r_ui=None, est=3.470480252442509, details={'was_impossible': False}),
#  Prediction(uid=10, iid=5049, r_ui=None, est=3.404867985109313, details={'was_impossible': False}),
#  Prediction(uid=10, iid=6383, r_ui=None, est=2.472753508173696, details={'was_impossible': False}),
#  Prediction(uid=10, iid=6953, r_ui=None, est=3.7501409153739633, details={'was_impossible': False}),
#  Prediction(uid=10, iid=7444, r_ui=None, est=3.254266831920114, details={'was_impossible': False}),
#  Prediction(uid=10, iid=7566, r_ui=None, est=4.222561055677398, details={'was_impossible': False}),
#  Prediction(uid=10, iid=53953, r_ui=None, est=3.6145706137779365, details={'was_impossible': False}),
#  Prediction(uid=11, iid=1207, r_ui=None, est=3.32171748199992, details={'was_impossible': False}),
#  Prediction(uid=11, iid=2329, r_ui=None, est=3.6200626500131374, details={'was_impossible': False}),
#  Prediction(uid=11, iid=2581, r_ui=None, est=2.9947602529393844, details={'was_impossible': False}),
#  Prediction(uid=11, iid=2881, r_ui=None, est=3.157123077069919, details={'was_impossible': False}),
#  Prediction(uid=11, iid=4210, r_ui=None, est=2.78658244774841, details={'was_impossible': False}),
#  Prediction(uid=11, iid=33669, r_ui=None, est=3.145239436630577, details={'was_impossible': False}),
#  Prediction(uid=11, iid=42723, r_ui=None, est=2.820595183849913, details={'was_impossible': False}),
#  Prediction(uid=12, iid=7, r_ui=None, est=3.0212265741346407, details={'was_impossible': False}),
#  Prediction(uid=12, iid=21, r_ui=None, est=3.742374564287375, details={'was_impossible': False}),
#  Prediction(uid=12, iid=47, r_ui=None, est=3.742624509067086, details={'was_impossible': False}),
#  Prediction(uid=12, iid=50, r_ui=None, est=4.349403178626475, details={'was_impossible': False}),
#  Prediction(uid=12, iid=141, r_ui=None, est=3.669294264395359, details={'was_impossible': False}),
#  Prediction(uid=12, iid=160, r_ui=None, est=1.5717376011322006, details={'was_impossible': False}),
#  Prediction(uid=12, iid=163, r_ui=None, est=2.776995089532571, details={'was_impossible': False}),
#  Prediction(uid=12, iid=203, r_ui=None, est=3.156807654046719, details={'was_impossible': False}),
#  Prediction(uid=12, iid=238, r_ui=None, est=2.6181235292079075, details={'was_impossible': False}),
#  Prediction(uid=12, iid=268, r_ui=None, est=3.337847381768163, details={'was_impossible': False}),
#  Prediction(uid=12, iid=292, r_ui=None, est=2.8602451833416933, details={'was_impossible': False}),
#  Prediction(uid=12, iid=293, r_ui=None, est=3.8547509628310923, details={'was_impossible': False}),
#  Prediction(uid=12, iid=344, r_ui=None, est=2.123931556424326, details={'was_impossible': False}),
#  Prediction(uid=12, iid=374, r_ui=None, est=1.7400515580986056, details={'was_impossible': False}),
#  Prediction(uid=12, iid=376, r_ui=None, est=2.840693632976233, details={'was_impossible': False}),
#  Prediction(uid=12, iid=380, r_ui=None, est=2.8952915291372103, details={'was_impossible': False}),
#  Prediction(uid=12, iid=477, r_ui=None, est=3.350452040268561, details={'was_impossible': False}),
#  Prediction(uid=12, iid=497, r_ui=None, est=4.030458864721289, details={'was_impossible': False}),
#  Prediction(uid=12, iid=538, r_ui=None, est=3.5417485095579, details={'was_impossible': False}),
#  Prediction(uid=12, iid=575, r_ui=None, est=2.300252014095402, details={'was_impossible': False}),
#  Prediction(uid=12, iid=592, r_ui=None, est=2.8568802022915283, details={'was_impossible': False}),
#  Prediction(uid=12, iid=603, r_ui=None, est=2.8454852824436365, details={'was_impossible': False}),
#  Prediction(uid=12, iid=608, r_ui=None, est=4.134965699735562, details={'was_impossible': False}),
#  Prediction(uid=12, iid=613, r_ui=None, est=3.295492063832932, details={'was_impossible': False}),
#  Prediction(uid=12, iid=765, r_ui=None, est=2.540467644595113, details={'was_impossible': False}),
#  Prediction(uid=12, iid=778, r_ui=None, est=4.085281646269764, details={'was_impossible': False}),
#  Prediction(uid=12, iid=780, r_ui=None, est=2.6761825598821867, details={'was_impossible': False}),
#  Prediction(uid=12, iid=858, r_ui=None, est=4.416236350364911, details={'was_impossible': False}),
#  Prediction(uid=12, iid=932, r_ui=None, est=3.5429151112459305, details={'was_impossible': False}),
#  Prediction(uid=12, iid=1013, r_ui=None, est=3.4177407540249947, details={'was_impossible': False}),
#  Prediction(uid=12, iid=1015, r_ui=None, est=2.712664158069711, details={'was_impossible': False}),
#  Prediction(uid=12, iid=1057, r_ui=None, est=3.5912273931171907, details={'was_impossible': False}),
#  Prediction(uid=12, iid=1135, r_ui=None, est=2.798072183660906, details={'was_impossible': False}),
#  Prediction(uid=12, iid=1136, r_ui=None, est=3.8415144410161197, details={'was_impossible': False}),
#  Prediction(uid=12, iid=1183, r_ui=None, est=3.5934379928086284, details={'was_impossible': False}),
#  Prediction(uid=12, iid=1188, r_ui=None, est=3.8691959616297886, details={'was_impossible': False}),
#  Prediction(uid=12, iid=1194, r_ui=None, est=2.8535742803332824, details={'was_impossible': False}),
#  Prediction(uid=12, iid=1200, r_ui=None, est=3.7652890208587313, details={'was_impossible': False}),
#  Prediction(uid=12, iid=1225, r_ui=None, est=4.48082075056789, details={'was_impossible': False}),
#  Prediction(uid=12, iid=1230, r_ui=None, est=3.6987793641649493, details={'was_impossible': False}),
#  Prediction(uid=12, iid=1231, r_ui=None, est=3.641566615683668, details={'was_impossible': False}),
#  Prediction(uid=12, iid=1243, r_ui=None, est=3.877041089050091, details={'was_impossible': False}),
#  Prediction(uid=12, iid=1258, r_ui=None, est=3.8176704813484226, details={'was_impossible': False}),
#  Prediction(uid=12, iid=1265, r_ui=None, est=3.6956533416101514, details={'was_impossible': False}),
#  Prediction(uid=12, iid=1267, r_ui=None, est=4.0791157551744615, details={'was_impossible': False}),
#  Prediction(uid=12, iid=1270, r_ui=None, est=3.748013397965867, details={'was_impossible': False}),
#  Prediction(uid=12, iid=1387, r_ui=None, est=3.5252458452961544, details={'was_impossible': False}),
#  Prediction(uid=12, iid=1391, r_ui=None, est=2.8643415317079244, details={'was_impossible': False}),
#  Prediction(uid=12, iid=1393, r_ui=None, est=3.714015974237948, details={'was_impossible': False}),
#  Prediction(uid=12, iid=1394, r_ui=None, est=3.511554554455954, details={'was_impossible': False}),
#  Prediction(uid=12, iid=1474, r_ui=None, est=2.0232992914455568, details={'was_impossible': False}),
#  Prediction(uid=12, iid=1552, r_ui=None, est=2.517917570784397, details={'was_impossible': False}),
#  Prediction(uid=12, iid=1586, r_ui=None, est=2.4085071381644694, details={'was_impossible': False}),
#  Prediction(uid=12, iid=1596, r_ui=None, est=3.5010018765227935, details={'was_impossible': False}),
#  Prediction(uid=12, iid=1644, r_ui=None, est=1.8445732884581378, details={'was_impossible': False}),
#  Prediction(uid=12, iid=1665, r_ui=None, est=2.652851463863642, details={'was_impossible': False}),
#  Prediction(uid=12, iid=1682, r_ui=None, est=3.7718295157576933, details={'was_impossible': False}),
#  Prediction(uid=12, iid=1777, r_ui=None, est=3.09999178023861, details={'was_impossible': False}),
#  Prediction(uid=12, iid=1876, r_ui=None, est=2.299093995353134, details={'was_impossible': False}),
#  Prediction(uid=12, iid=1884, r_ui=None, est=3.148737661321985, details={'was_impossible': False}),
#  Prediction(uid=12, iid=1947, r_ui=None, est=3.2937209280712367, details={'was_impossible': False}),
#  Prediction(uid=12, iid=2052, r_ui=None, est=2.1257632553613233, details={'was_impossible': False}),
#  Prediction(uid=12, iid=2081, r_ui=None, est=3.175100370900001, details={'was_impossible': False}),
#  Prediction(uid=12, iid=2108, r_ui=None, est=3.4194302906262584, details={'was_impossible': False}),
#  Prediction(uid=12, iid=2174, r_ui=None, est=3.1938670406764746, details={'was_impossible': False}),
#  Prediction(uid=12, iid=2318, r_ui=None, est=3.659607854097284, details={'was_impossible': False}),
#  Prediction(uid=12, iid=2336, r_ui=None, est=4.185273971813509, details={'was_impossible': False}),
#  Prediction(uid=12, iid=2374, r_ui=None, est=2.3443034614046168, details={'was_impossible': False}),
#  Prediction(uid=12, iid=2381, r_ui=None, est=1.4789414040376743, details={'was_impossible': False}),
#  Prediction(uid=12, iid=2406, r_ui=None, est=3.3473868684217685, details={'was_impossible': False}),
#  Prediction(uid=12, iid=2420, r_ui=None, est=2.8248422448000934, details={'was_impossible': False}),
#  Prediction(uid=12, iid=2459, r_ui=None, est=2.8440842795284254, details={'was_impossible': False}),
#  Prediction(uid=12, iid=2469, r_ui=None, est=2.9297997551780357, details={'was_impossible': False}),
#  Prediction(uid=12, iid=2500, r_ui=None, est=2.2794002643705378, details={'was_impossible': False}),
#  Prediction(uid=12, iid=2599, r_ui=None, est=3.554276256969066, details={'was_impossible': False}),
#  Prediction(uid=12, iid=2762, r_ui=None, est=3.731532711620858, details={'was_impossible': False}),
#  Prediction(uid=12, iid=2770, r_ui=None, est=2.259835311777088, details={'was_impossible': False}),
#  Prediction(uid=12, iid=2797, r_ui=None, est=3.4130590201487685, details={'was_impossible': False}),
#  Prediction(uid=12, iid=2863, r_ui=None, est=3.603783423069213, details={'was_impossible': False}),
#  Prediction(uid=12, iid=2881, r_ui=None, est=2.735561694010833, details={'was_impossible': False}),
#  Prediction(uid=12, iid=2901, r_ui=None, est=2.9853408888660775, details={'was_impossible': False}),
#  Prediction(uid=12, iid=2948, r_ui=None, est=3.591133125771621, details={'was_impossible': False}),
#  Prediction(uid=12, iid=2987, r_ui=None, est=3.2413739835935593, details={'was_impossible': False}),
#  Prediction(uid=12, iid=3033, r_ui=None, est=2.9278594663070985, details={'was_impossible': False}),
#  Prediction(uid=12, iid=3089, r_ui=None, est=3.9883296288862002, details={'was_impossible': False}),
#  Prediction(uid=12, iid=3148, r_ui=None, est=3.7525544006090685, details={'was_impossible': False}),
#  Prediction(uid=12, iid=3186, r_ui=None, est=3.6880977566076156, details={'was_impossible': False}),
#  Prediction(uid=12, iid=3249, r_ui=None, est=2.9039953535612493, details={'was_impossible': False}),
#  Prediction(uid=12, iid=3255, r_ui=None, est=3.4058047594316627, details={'was_impossible': False}),
#  Prediction(uid=12, iid=3262, r_ui=None, est=3.053773812862048, details={'was_impossible': False}),
#  Prediction(uid=12, iid=3264, r_ui=None, est=2.645335231975146, details={'was_impossible': False}),
#  Prediction(uid=12, iid=3274, r_ui=None, est=2.818196581013451, details={'was_impossible': False}),
#  Prediction(uid=12, iid=3397, r_ui=None, est=3.402126286722278, details={'was_impossible': False}),
#  Prediction(uid=12, iid=3435, r_ui=None, est=4.259782063925025, details={'was_impossible': False}),
#  Prediction(uid=12, iid=3478, r_ui=None, est=2.940484907402785, details={'was_impossible': False}),
#  Prediction(uid=12, iid=3538, r_ui=None, est=3.4229522384197586, details={'was_impossible': False}),
#  Prediction(uid=12, iid=3578, r_ui=None, est=3.6998661059932116, details={'was_impossible': False}),
#  Prediction(uid=12, iid=3608, r_ui=None, est=2.755065954047052, details={'was_impossible': False}),
#  Prediction(uid=12, iid=3633, r_ui=None, est=3.2149260003004154, details={'was_impossible': False}),
#  Prediction(uid=12, iid=3751, r_ui=None, est=3.561542368997344, details={'was_impossible': False}),
#  Prediction(uid=12, iid=3809, r_ui=None, est=2.956713241371852, details={'was_impossible': False}),
#  Prediction(uid=12, iid=3823, r_ui=None, est=3.37453264106109, details={'was_impossible': False}),
#  Prediction(uid=12, iid=3897, r_ui=None, est=3.9353333750046495, details={'was_impossible': False}),
#  Prediction(uid=12, iid=4022, r_ui=None, est=3.53315602132239, details={'was_impossible': False}),
#  Prediction(uid=12, iid=4027, r_ui=None, est=4.09676665733998, details={'was_impossible': False}),
#  Prediction(uid=12, iid=4039, r_ui=None, est=2.9968464314385796, details={'was_impossible': False}),
#  Prediction(uid=12, iid=4080, r_ui=None, est=2.7672708000463406, details={'was_impossible': False}),
#  Prediction(uid=12, iid=4100, r_ui=None, est=1.6264981267765588, details={'was_impossible': False}),
#  Prediction(uid=12, iid=4105, r_ui=None, est=3.6698283205355042, details={'was_impossible': False}),
#  Prediction(uid=12, iid=4135, r_ui=None, est=2.822808551923938, details={'was_impossible': False}),
#  Prediction(uid=12, iid=4246, r_ui=None, est=3.7898056992254254, details={'was_impossible': False}),
#  Prediction(uid=12, iid=4378, r_ui=None, est=3.661182137655147, details={'was_impossible': False}),
#  Prediction(uid=12, iid=4529, r_ui=None, est=3.784954693487724, details={'was_impossible': False}),
#  Prediction(uid=12, iid=4559, r_ui=None, est=2.107469639489827, details={'was_impossible': False}),
#  Prediction(uid=12, iid=4703, r_ui=None, est=3.563345508304776, details={'was_impossible': False}),
#  Prediction(uid=12, iid=5013, r_ui=None, est=3.434953109217542, details={'was_impossible': False}),
#  Prediction(uid=12, iid=5339, r_ui=None, est=3.522664681681384, details={'was_impossible': False}),
#  Prediction(uid=12, iid=5459, r_ui=None, est=2.4505489727266925, details={'was_impossible': False}),
#  Prediction(uid=12, iid=5481, r_ui=None, est=1.966469952550533, details={'was_impossible': False}),
#  Prediction(uid=12, iid=5785, r_ui=None, est=1.527489577659392, details={'was_impossible': False}),
#  Prediction(uid=12, iid=6268, r_ui=None, est=3.6409889021330555, details={'was_impossible': False}),
#  Prediction(uid=12, iid=6296, r_ui=None, est=3.625299785825993, details={'was_impossible': False}),
#  Prediction(uid=12, iid=6297, r_ui=None, est=3.283716103478327, details={'was_impossible': False}),
#  Prediction(uid=12, iid=6539, r_ui=None, est=3.4239454622089096, details={'was_impossible': False}),
#  Prediction(uid=12, iid=6711, r_ui=None, est=3.9434666371358005, details={'was_impossible': False}),
#  Prediction(uid=12, iid=6750, r_ui=None, est=3.053180253148838, details={'was_impossible': False}),
#  Prediction(uid=12, iid=6863, r_ui=None, est=3.601451558227637, details={'was_impossible': False}),
#  Prediction(uid=12, iid=6979, r_ui=None, est=3.408231049273164, details={'was_impossible': False}),
#  Prediction(uid=12, iid=6993, r_ui=None, est=3.9585020137406106, details={'was_impossible': False}),
#  Prediction(uid=12, iid=8017, r_ui=None, est=3.3875881438435402, details={'was_impossible': False}),
#  Prediction(uid=12, iid=8040, r_ui=None, est=3.0458859976048815, details={'was_impossible': False}),
#  Prediction(uid=12, iid=8644, r_ui=None, est=3.0739088456905796, details={'was_impossible': False}),
# ...
#  Prediction(uid=23, iid=1228, r_ui=None, est=4.506300276367454, details={'was_impossible': False}),
#  Prediction(uid=23, iid=1249, r_ui=None, est=4.1820340375658205, details={'was_impossible': False}),
#  Prediction(uid=23, iid=1265, r_ui=None, est=4.298160732476951, details={'was_impossible': False}),
#  Prediction(uid=23, iid=1291, r_ui=None, est=4.538254068958974, details={'was_impossible': False}),
#  Prediction(uid=23, iid=1344, r_ui=None, est=4.118167530406224, details={'was_impossible': False}),
#  Prediction(uid=23, iid=1357, r_ui=None, est=4.727715687713841, details={'was_impossible': False}),
#  Prediction(uid=23, iid=1371, r_ui=None, est=2.8908522471998466, details={'was_impossible': False}),
#  Prediction(uid=23, iid=1396, r_ui=None, est=4.049538245108869, details={'was_impossible': False}),
#  Prediction(uid=23, iid=1449, r_ui=None, est=4.377448841398415, details={'was_impossible': False}),
#  Prediction(uid=23, iid=1573, r_ui=None, est=3.675360402202445, details={'was_impossible': False}),
#  Prediction(uid=23, iid=1584, r_ui=None, est=4.050015559228707, details={'was_impossible': False}),
#  Prediction(uid=23, iid=1617, r_ui=None, est=4.570572990559367, details={'was_impossible': False}),
#  Prediction(uid=23, iid=1625, r_ui=None, est=4.061069994605219, details={'was_impossible': False}),
#  Prediction(uid=23, iid=1641, r_ui=None, est=4.340433294616572, details={'was_impossible': False}),
#  Prediction(uid=23, iid=1673, r_ui=None, est=4.128477841158895, details={'was_impossible': False}),
#  Prediction(uid=23, iid=1729, r_ui=None, est=4.008998705606671, details={'was_impossible': False}),
#  Prediction(uid=23, iid=1810, r_ui=None, est=3.7788945785595427, details={'was_impossible': False}),
#  Prediction(uid=23, iid=1957, r_ui=None, est=4.039276772893698, details={'was_impossible': False}),
#  Prediction(uid=23, iid=2028, r_ui=None, est=4.869566613624296, details={'was_impossible': False}),
#  Prediction(uid=23, iid=2058, r_ui=None, est=3.6667421083723286, details={'was_impossible': False}),
#  Prediction(uid=23, iid=2064, r_ui=None, est=4.3797767701644155, details={'was_impossible': False}),
#  Prediction(uid=23, iid=2108, r_ui=None, est=3.9037722973720697, details={'was_impossible': False}),
#  Prediction(uid=23, iid=2166, r_ui=None, est=4.124080716770911, details={'was_impossible': False}),
#  Prediction(uid=23, iid=2245, r_ui=None, est=3.9018265113475463, details={'was_impossible': False}),
#  Prediction(uid=23, iid=2262, r_ui=None, est=3.6888619547901684, details={'was_impossible': False}),
#  Prediction(uid=23, iid=2294, r_ui=None, est=3.6469717297548767, details={'was_impossible': False}),
#  Prediction(uid=23, iid=2301, r_ui=None, est=3.7393268023815396, details={'was_impossible': False}),
#  Prediction(uid=23, iid=2336, r_ui=None, est=4.057626652836823, details={'was_impossible': False}),
#  Prediction(uid=23, iid=2411, r_ui=None, est=3.5882501444881583, details={'was_impossible': False}),
#  Prediction(uid=23, iid=2417, r_ui=None, est=3.374083613429908, details={'was_impossible': False}),
#  Prediction(uid=23, iid=2470, r_ui=None, est=3.762053468468199, details={'was_impossible': False}),
#  Prediction(uid=23, iid=2528, r_ui=None, est=3.4902041076297063, details={'was_impossible': False}),
#  Prediction(uid=23, iid=2611, r_ui=None, est=4.391264930415648, details={'was_impossible': False}),
#  Prediction(uid=23, iid=2692, r_ui=None, est=4.2770734428199955, details={'was_impossible': False}),
#  Prediction(uid=23, iid=2797, r_ui=None, est=4.179555796898358, details={'was_impossible': False}),
#  Prediction(uid=23, iid=2871, r_ui=None, est=3.9252702329757483, details={'was_impossible': False}),
#  Prediction(uid=23, iid=2928, r_ui=None, est=3.749528443386135, details={'was_impossible': False}),
#  Prediction(uid=23, iid=2942, r_ui=None, est=3.2120338751931596, details={'was_impossible': False}),
#  Prediction(uid=23, iid=3019, r_ui=None, est=4.044595674140085, details={'was_impossible': False}),
#  Prediction(uid=23, iid=3060, r_ui=None, est=4.130942859269736, details={'was_impossible': False}),
#  Prediction(uid=23, iid=3105, r_ui=None, est=4.127587590694239, details={'was_impossible': False}),
#  Prediction(uid=23, iid=3135, r_ui=None, est=4.029383032373449, details={'was_impossible': False}),
#  Prediction(uid=23, iid=3142, r_ui=None, est=4.170861377171275, details={'was_impossible': False}),
#  Prediction(uid=24, iid=50, r_ui=None, est=4.356204128575752, details={'was_impossible': False}),
#  Prediction(uid=24, iid=1221, r_ui=None, est=4.227443726172611, details={'was_impossible': False}),
#  Prediction(uid=24, iid=1918, r_ui=None, est=3.765170231378368, details={'was_impossible': False}),
#  Prediction(uid=24, iid=2490, r_ui=None, est=3.872821833488145, details={'was_impossible': False}),
#  Prediction(uid=24, iid=2581, r_ui=None, est=3.652203906775097, details={'was_impossible': False}),
#  Prediction(uid=24, iid=3623, r_ui=None, est=3.9188586947272, details={'was_impossible': False}),
#  Prediction(uid=24, iid=3863, r_ui=None, est=3.414836412328254, details={'was_impossible': False}),
#  Prediction(uid=24, iid=58559, r_ui=None, est=4.245959344998772, details={'was_impossible': False}),
#  Prediction(uid=25, iid=21, r_ui=None, est=3.5324251389249848, details={'was_impossible': False}),
#  Prediction(uid=25, iid=25, r_ui=None, est=3.433619824998055, details={'was_impossible': False}),
#  Prediction(uid=25, iid=110, r_ui=None, est=3.740470980582977, details={'was_impossible': False}),
#  Prediction(uid=25, iid=150, r_ui=None, est=3.82034367754409, details={'was_impossible': False}),
#  Prediction(uid=25, iid=161, r_ui=None, est=3.538965685616424, details={'was_impossible': False}),
#  Prediction(uid=25, iid=185, r_ui=None, est=3.171429985946541, details={'was_impossible': False}),
#  Prediction(uid=25, iid=215, r_ui=None, est=3.977649901472292, details={'was_impossible': False}),
#  Prediction(uid=25, iid=260, r_ui=None, est=3.7715041154018976, details={'was_impossible': False}),
#  Prediction(uid=25, iid=261, r_ui=None, est=2.937273440139329, details={'was_impossible': False}),
#  Prediction(uid=25, iid=292, r_ui=None, est=3.343311665911142, details={'was_impossible': False}),
#  Prediction(uid=25, iid=315, r_ui=None, est=2.6323252695078843, details={'was_impossible': False}),
#  Prediction(uid=25, iid=380, r_ui=None, est=3.3469789729520136, details={'was_impossible': False}),
#  Prediction(uid=25, iid=432, r_ui=None, est=2.5066085472063233, details={'was_impossible': False}),
#  Prediction(uid=25, iid=457, r_ui=None, est=3.856966512551934, details={'was_impossible': False}),
#  Prediction(uid=25, iid=480, r_ui=None, est=3.5368675268999596, details={'was_impossible': False}),
#  Prediction(uid=25, iid=595, r_ui=None, est=3.2203962745564896, details={'was_impossible': False}),
#  Prediction(uid=26, iid=455, r_ui=None, est=2.4454671386129516, details={'was_impossible': False}),
#  Prediction(uid=26, iid=590, r_ui=None, est=3.784568335757226, details={'was_impossible': False}),
#  Prediction(uid=26, iid=1270, r_ui=None, est=3.90848296915225, details={'was_impossible': False}),
#  Prediction(uid=26, iid=2382, r_ui=None, est=2.0388233315780715, details={'was_impossible': False}),
#  Prediction(uid=26, iid=4951, r_ui=None, est=3.570823153268166, details={'was_impossible': False}),
#  Prediction(uid=26, iid=72249, r_ui=None, est=3.650950668413434, details={'was_impossible': False}),
#  Prediction(uid=27, iid=260, r_ui=None, est=4.545859790900027, details={'was_impossible': False}),
#  Prediction(uid=27, iid=356, r_ui=None, est=4.610455951285746, details={'was_impossible': False}),
#  Prediction(uid=27, iid=597, r_ui=None, est=4.623849698824693, details={'was_impossible': False}),
#  Prediction(uid=27, iid=1008, r_ui=None, est=4.191479529645107, details={'was_impossible': False}),
#  Prediction(uid=27, iid=1082, r_ui=None, est=4.502649458801657, details={'was_impossible': False}),
#  Prediction(uid=27, iid=1101, r_ui=None, est=4.1122000327034804, details={'was_impossible': False}),
#  Prediction(uid=27, iid=1196, r_ui=None, est=4.427665134842614, details={'was_impossible': False}),
#  Prediction(uid=27, iid=1931, r_ui=None, est=4.847440376867865, details={'was_impossible': False}),
#  Prediction(uid=27, iid=1952, r_ui=None, est=4.654406775600539, details={'was_impossible': False}),
#  Prediction(uid=27, iid=2145, r_ui=None, est=4.262225675178824, details={'was_impossible': False}),
#  Prediction(uid=27, iid=3098, r_ui=None, est=4.268029955797996, details={'was_impossible': False}),
#  Prediction(uid=27, iid=3365, r_ui=None, est=4.645739538589991, details={'was_impossible': False}),
#  Prediction(uid=27, iid=3671, r_ui=None, est=4.669157250207098, details={'was_impossible': False}),
#  Prediction(uid=28, iid=610, r_ui=None, est=4.133108390278769, details={'was_impossible': False}),
#  Prediction(uid=28, iid=1407, r_ui=None, est=4.234156736193225, details={'was_impossible': False}),
#  Prediction(uid=28, iid=1580, r_ui=None, est=4.642302373166563, details={'was_impossible': False}),
#  Prediction(uid=28, iid=1584, r_ui=None, est=4.4959366179125295, details={'was_impossible': False}),
#  Prediction(uid=28, iid=1909, r_ui=None, est=4.1999041947251134, details={'was_impossible': False}),
#  Prediction(uid=28, iid=2021, r_ui=None, est=4.482336637096225, details={'was_impossible': False}),
#  Prediction(uid=28, iid=2311, r_ui=None, est=4.014759464899951, details={'was_impossible': False}),
#  Prediction(uid=28, iid=2723, r_ui=None, est=4.081086078391871, details={'was_impossible': False}),
#  Prediction(uid=29, iid=69, r_ui=None, est=3.679218561761758, details={'was_impossible': False}),
#  Prediction(uid=29, iid=175, r_ui=None, est=3.7467760804688326, details={'was_impossible': False}),
#  Prediction(uid=29, iid=562, r_ui=None, est=3.730556132014684, details={'was_impossible': False}),
#  Prediction(uid=29, iid=1354, r_ui=None, est=3.7570679719599025, details={'was_impossible': False}),
#  Prediction(uid=29, iid=1619, r_ui=None, est=3.444352021934692, details={'was_impossible': False}),
#  Prediction(uid=29, iid=55553, r_ui=None, est=3.3245366242612695, details={'was_impossible': False}),
#  Prediction(uid=29, iid=69784, r_ui=None, est=3.3275797157982714, details={'was_impossible': False}),
#  Prediction(uid=29, iid=72641, r_ui=None, est=3.6400061740021195, details={'was_impossible': False}),
#  Prediction(uid=30, iid=410, r_ui=None, est=3.254282237111514, details={'was_impossible': False}),
#  Prediction(uid=30, iid=1580, r_ui=None, est=3.6331363757297668, details={'was_impossible': False}),
#  Prediction(uid=30, iid=4701, r_ui=None, est=3.622100346763639, details={'was_impossible': False}),
#  Prediction(uid=30, iid=33004, r_ui=None, est=3.8160110504034668, details={'was_impossible': False}),
#  Prediction(uid=30, iid=33794, r_ui=None, est=4.1228777892892206, details={'was_impossible': False}),
#  Prediction(uid=30, iid=91542, r_ui=None, est=3.580343888500255, details={'was_impossible': False}),
#  Prediction(uid=31, iid=47, r_ui=None, est=2.7681279802422765, details={'was_impossible': False}),
#  Prediction(uid=31, iid=110, r_ui=None, est=2.7935081868122698, details={'was_impossible': False}),
#  Prediction(uid=31, iid=141, r_ui=None, est=2.416331544077981, details={'was_impossible': False}),
#  Prediction(uid=31, iid=161, r_ui=None, est=2.8631379564198682, details={'was_impossible': False}),
#  Prediction(uid=31, iid=253, r_ui=None, est=2.1591960662078153, details={'was_impossible': False}),
#  Prediction(uid=31, iid=260, r_ui=None, est=2.840185505122204, details={'was_impossible': False}),
#  Prediction(uid=31, iid=377, r_ui=None, est=2.8926036648255784, details={'was_impossible': False}),
#  Prediction(uid=31, iid=434, r_ui=None, est=2.233354952858491, details={'was_impossible': False}),
#  Prediction(uid=31, iid=454, r_ui=None, est=2.602607858702972, details={'was_impossible': False}),
#  Prediction(uid=31, iid=474, r_ui=None, est=2.7141107899547166, details={'was_impossible': False}),
#  Prediction(uid=31, iid=587, r_ui=None, est=2.7047000351352257, details={'was_impossible': False}),
#  Prediction(uid=31, iid=648, r_ui=None, est=2.318546692232808, details={'was_impossible': False}),
#  Prediction(uid=31, iid=736, r_ui=None, est=2.5376764708440462, details={'was_impossible': False}),
#  Prediction(uid=31, iid=932, r_ui=None, est=3.0559198149605473, details={'was_impossible': False}),
#  Prediction(uid=31, iid=1036, r_ui=None, est=3.075809165341425, details={'was_impossible': False}),
#  Prediction(uid=31, iid=1079, r_ui=None, est=2.8232438620338622, details={'was_impossible': False}),
#  Prediction(uid=31, iid=1258, r_ui=None, est=3.163233633512183, details={'was_impossible': False}),
#  Prediction(uid=31, iid=1393, r_ui=None, est=2.6978026732818243, details={'was_impossible': False}),
#  Prediction(uid=31, iid=1459, r_ui=None, est=2.2568755467584856, details={'was_impossible': False}),
#  Prediction(uid=31, iid=1479, r_ui=None, est=2.3981317220623337, details={'was_impossible': False}),
#  Prediction(uid=31, iid=1625, r_ui=None, est=2.7279854333758387, details={'was_impossible': False}),
#  Prediction(uid=31, iid=1641, r_ui=None, est=2.701302612249927, details={'was_impossible': False}),
#  Prediction(uid=31, iid=1693, r_ui=None, est=2.501269506418444, details={'was_impossible': False}),
#  Prediction(uid=31, iid=1923, r_ui=None, est=2.4931921037179414, details={'was_impossible': False}),
#  Prediction(uid=31, iid=2028, r_ui=None, est=2.9345317246399034, details={'was_impossible': False}),
#  Prediction(uid=31, iid=2081, r_ui=None, est=2.5390626629253332, details={'was_impossible': False}),
#  Prediction(uid=31, iid=2141, r_ui=None, est=2.6120131872651235, details={'was_impossible': False}),
#  Prediction(uid=31, iid=2262, r_ui=None, est=2.0893893165187003, details={'was_impossible': False}),
#  Prediction(uid=31, iid=2321, r_ui=None, est=2.4794996585801816, details={'was_impossible': False}),
#  Prediction(uid=31, iid=2396, r_ui=None, est=2.8909291387618734, details={'was_impossible': False}),
#  Prediction(uid=31, iid=2710, r_ui=None, est=1.7954285689856846, details={'was_impossible': False}),
#  Prediction(uid=31, iid=3004, r_ui=None, est=1.5681901101197435, details={'was_impossible': False}),
#  Prediction(uid=31, iid=3081, r_ui=None, est=2.381044480975707, details={'was_impossible': False}),
#  Prediction(uid=31, iid=3175, r_ui=None, est=2.588736008105033, details={'was_impossible': False}),
#  Prediction(uid=31, iid=3206, r_ui=None, est=2.236217110940393, details={'was_impossible': False}),
#  Prediction(uid=31, iid=3253, r_ui=None, est=2.666296143804342, details={'was_impossible': False}),
#  Prediction(uid=31, iid=3408, r_ui=None, est=2.700152455174749, details={'was_impossible': False}),
#  Prediction(uid=31, iid=3420, r_ui=None, est=2.983710281279601, details={'was_impossible': False}),
#  Prediction(uid=31, iid=3481, r_ui=None, est=2.761813604672744, details={'was_impossible': False}),
#  Prediction(uid=31, iid=3525, r_ui=None, est=2.365692488393177, details={'was_impossible': False}),
#  Prediction(uid=31, iid=3755, r_ui=None, est=2.170051011317216, details={'was_impossible': False}),
#  Prediction(uid=31, iid=3793, r_ui=None, est=2.296603987630645, details={'was_impossible': False}),
#  Prediction(uid=31, iid=3841, r_ui=None, est=1.986123740494162, details={'was_impossible': False}),
#  Prediction(uid=31, iid=4174, r_ui=None, est=2.7697427086816893, details={'was_impossible': False}),
#  Prediction(uid=31, iid=4392, r_ui=None, est=2.760596991525696, details={'was_impossible': False}),
#  Prediction(uid=31, iid=4564, r_ui=None, est=2.282426984245399, details={'was_impossible': False}),
#  Prediction(uid=31, iid=4639, r_ui=None, est=1.8348984883163462, details={'was_impossible': False}),
#  Prediction(uid=31, iid=4973, r_ui=None, est=2.7795862055184406, details={'was_impossible': False}),
#  Prediction(uid=31, iid=4995, r_ui=None, est=2.9105823554871915, details={'was_impossible': False}),
#  Prediction(uid=31, iid=5377, r_ui=None, est=2.548908840043862, details={'was_impossible': False}),
#  Prediction(uid=31, iid=5472, r_ui=None, est=2.8898056234979084, details={'was_impossible': False}),
#  ...]

# %%
pred_df = pd.DataFrame(ratings_predictions)
pred_df
# Out:
#             uid   iid  r_ui       est                    details
# 0             1  2011  None  3.333643  {'was_impossible': False}
# 1             1  4144  None  4.043976  {'was_impossible': False}
# 2             1  5767  None  3.784905  {'was_impossible': False}
# 3             1  6711  None  3.739298  {'was_impossible': False}
# 4             1  7318  None  3.458778  {'was_impossible': False}
# ...         ...   ...   ...       ...                        ...
# 5000014  162541  4079  None  3.381690  {'was_impossible': False}
# 5000015  162541  4467  None  3.907179  {'was_impossible': False}
# 5000016  162541  4980  None  2.554581  {'was_impossible': False}
# 5000017  162541  5689  None  2.785085  {'was_impossible': False}
# 5000018  162541  7153  None  4.637555  {'was_impossible': False}
#
# [5000019 rows x 5 columns]

# %% [markdown]
# ### Get a rating for every user-movie pair in test dataframe and generate csv submission

# %%
# Rename predictions to original names
pred_df = pred_df.rename(columns={'uid':'userId', 'iid':'movieId','est':'rating'})
pred_df.drop(['r_ui','details'], axis=1, inplace=True)

# %%
pred_df.head()
# Out:
#    userId  movieId    rating
# 0       1     2011  3.333643
# 1       1     4144  4.043976
# 2       1     5767  3.784905
# 3       1     6711  3.739298
# 4       1     7318  3.458778

# %%
# Join userId and movieId into single Id column
pred_df['Id']=pred_df.apply(lambda x:'%s_%s' % (x['userId'], x['movieId']), axis=1)
pred_df['Id']=pred_df.apply(lambda x:'%s_%s' % (x['userId'], x['movieId']), axis=1)

# %%
pred_df.head()
# Out:
#    userId  movieId    rating      Id
# 0       1     2011  3.333643  1_2011
# 1       1     4144  4.043976  1_4144
# 2       1     5767  3.784905  1_5767
# 3       1     6711  3.739298  1_6711
# 4       1     7318  3.458778  1_7318

# %%
pred_df.drop(['userId', 'movieId'], inplace=True, axis=1)

# %%
pred_df = pred_df[['Id', 'rating']]
pred_df.head()
# Out:
#        Id    rating
# 0  1_2011  3.333643
# 1  1_4144  4.043976
# 2  1_5767  3.784905
# 3  1_6711  3.739298
# 4  1_7318  3.458778

# %%
pred_df['rating'] = pred_df['rating'].apply(lambda x: round(x * 2) / 2)

# %%
pred_df.head()
# Out:
#        Id  rating
# 0  1_2011     3.5
# 1  1_4144     4.0
# 2  1_5767     4.0
# 3  1_6711     3.5
# 4  1_7318     3.5

# %%
pred_df.to_csv('Shawn_Johnson_submission.csv', index=False)

# %%
pred_df.shape
# Out:
# (5000019, 2)
